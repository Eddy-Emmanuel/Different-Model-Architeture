# %%
from warnings import filterwarnings
filterwarnings(action="ignore")

import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, Model, Sequential, Input, Model

# %% [markdown]
# ## Lenet5 Model Architecture

# %%
lenet5 = Sequential([
    Input(shape=(32, 32, 1), name="Input"),
    layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation="tanh"),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation="tanh"),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=120, kernel_size=(5, 5), strides=(1, 1), activation="tanh"),
    layers.Flatten(), 
    layers.Dense(units=84, activation="tanh"),
    layers.Dense(units=10, activation="softmax")
])

lenet5.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_207 (Conv2D)         (None, 28, 28, 6)         156
#
#  average_pooling2d_4 (Avera  (None, 14, 14, 6)         0
#  gePooling2D)
#
#  conv2d_208 (Conv2D)         (None, 10, 10, 16)        2416
#
#  average_pooling2d_5 (Avera  (None, 5, 5, 16)          0
#  gePooling2D)
#
#  conv2d_209 (Conv2D)         (None, 1, 1, 120)         48120
#
#  flatten_10 (Flatten)        (None, 120)               0
#
#  dense_35 (Dense)            (None, 84)                10164
#
#  dense_36 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 61706 (241.04 KB)
# Trainable params: 61706 (241.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## AlexNet Architecture

# %%
alexnet = Sequential([
    Input(shape=(227, 227, 3), name="Input"),
    layers.Conv2D(filters=96, kernel_size=(11,11), strides=4, padding="valid", activation="relu"),
    layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="valid"),
    layers.Conv2D(filters=256, kernel_size=(5, 5), strides=(1, 1), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="valid"),
    layers.Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu"),
    layers.Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu"),
    layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu"),
    layers.Flatten(),
    layers.Dense(units=4096, activation="relu"),
    layers.Dropout(rate=0.5),
    layers.Dense(units=4096, activation="relu"),
    layers.Dropout(rate=0.5),
    layers.Dense(units=1000, activation="softmax")
])

alexnet.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_210 (Conv2D)         (None, 55, 55, 96)        34944
#
#  max_pooling2d_66 (MaxPooli  (None, 27, 27, 96)        0
#  ng2D)
#
#  conv2d_211 (Conv2D)         (None, 27, 27, 256)       614656
#
#  max_pooling2d_67 (MaxPooli  (None, 13, 13, 256)       0
#  ng2D)
#
#  conv2d_212 (Conv2D)         (None, 13, 13, 384)       885120
#
#  conv2d_213 (Conv2D)         (None, 13, 13, 384)       1327488
#
#  conv2d_214 (Conv2D)         (None, 13, 13, 256)       884992
#
#  flatten_11 (Flatten)        (None, 43264)             0
#
#  dense_37 (Dense)            (None, 4096)              177213440
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_38 (Dense)            (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_39 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 201838952 (769.95 MB)
# Trainable params: 201838952 (769.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## GoogleNet Architecture

# %%
def Inceptron(x, filters):
    inception_1 = layers.Conv2D(filters=filters[0], kernel_size=(1, 1), padding="same", activation="relu")(x)
    
    inception_2 = layers.Conv2D(filters=filters[1], kernel_size=(3, 3), padding="same", activation="relu")(x_1)
    inception_3 = layers.Conv2D(filters=filters[2], kernel_size=(3, 3), padding="same", activation="relu")(x_1)
    
    inception_4 = layers.Conv2D(filters=filters[3], kernel_size=(5, 5), padding="same", activation="relu")(x_1)
    inception_5 = layers.Conv2D(filters=filters[4], kernel_size=(5, 5), padding="same", activation="relu")(x_1)
    
    inception_6 = layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding="same")(x_1)
    inception_7 = layers.Conv2D(filters=filters[5], kernel_size=(1, 1), padding="same", activation="relu")(x_1)
    
    return layers.concatenate([inception_1, inception_3, inception_5, inception_7], axis=-1)

model_input = Input(shape=(224, 224, 3), name="Input")
x_1 = layers.Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding="same", activation="relu")(model_input)
x_1 = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(x_1)

x_1 = layers.Conv2D(filters=192, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(x_1)
x_1 = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(x_1)

x_1 = Inceptron(x_1, [64, 96, 128, 16, 32, 32])
x_1 = Inceptron(x_1, [128, 128, 192, 32, 96, 64])

x_1 = layers.MaxPooling2D(pool_size=(3,3), strides=(2, 2), padding="same")(x_1)

x_1 = Inceptron(x_1, [192, 96, 208, 16, 48, 64])
x_1 = Inceptron(x_1, [160, 112, 224, 24, 64, 64])
x_1 = Inceptron(x_1, [128, 256, 256, 24, 64, 64])
x_1 = Inceptron(x_1, [112, 144, 288, 32, 64, 64])
x_1 = Inceptron(x_1, [256, 160, 320, 32, 128, 128])

x_1 = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(x_1)

x_1 = Inceptron(x_1, [256, 160, 320, 32, 128, 128])
x_1 = Inceptron(x_1, [384, 192, 384, 48, 128, 128])

x_1 = layers.AveragePooling2D(pool_size=(7, 7), strides=(1, 1), padding="same")(x_1)
x_1 = layers.Dropout(rate=0.4)(x_1)
x_1 = layers.Flatten()(x_1)

x_1 = layers.Dense(1000, activation="linear")(x_1)

model_output = layers.Dense(1000, activation="softmax")(x_1)

googlenet = Model(inputs=model_input, outputs=model_output)

googlenet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Input (InputLayer)          [(None, 224, 224, 3)]        0         []
#
#  conv2d_215 (Conv2D)         (None, 112, 112, 64)         9472      ['Input[0][0]']
#
#  max_pooling2d_68 (MaxPooli  (None, 56, 56, 64)           0         ['conv2d_215[0][0]']
#  ng2D)
#
#  conv2d_216 (Conv2D)         (None, 56, 56, 192)          110784    ['max_pooling2d_68[0][0]']
#
#  max_pooling2d_69 (MaxPooli  (None, 28, 28, 192)          0         ['conv2d_216[0][0]']
#  ng2D)
#
#  conv2d_217 (Conv2D)         (None, 28, 28, 64)           12352     ['max_pooling2d_69[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 28, 28, 128)          221312    ['max_pooling2d_69[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 28, 28, 32)           153632    ['max_pooling2d_69[0][0]']
#
#  conv2d_222 (Conv2D)         (None, 28, 28, 32)           6176      ['max_pooling2d_69[0][0]']
#
#  concatenate_18 (Concatenat  (None, 28, 28, 256)          0         ['conv2d_217[0][0]',
#  e)                                                                  'conv2d_219[0][0]',
#                                                                      'conv2d_221[0][0]',
#                                                                      'conv2d_222[0][0]']
#
#  conv2d_223 (Conv2D)         (None, 28, 28, 128)          32896     ['concatenate_18[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 28, 28, 192)          442560    ['concatenate_18[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 28, 28, 96)           614496    ['concatenate_18[0][0]']
#
#  conv2d_228 (Conv2D)         (None, 28, 28, 64)           16448     ['concatenate_18[0][0]']
#
#  concatenate_19 (Concatenat  (None, 28, 28, 480)          0         ['conv2d_223[0][0]',
#  e)                                                                  'conv2d_225[0][0]',
#                                                                      'conv2d_227[0][0]',
#                                                                      'conv2d_228[0][0]']
#
#  max_pooling2d_72 (MaxPooli  (None, 14, 14, 480)          0         ['concatenate_19[0][0]']
#  ng2D)
#
#  conv2d_229 (Conv2D)         (None, 14, 14, 192)          92352     ['max_pooling2d_72[0][0]']
#
#  conv2d_231 (Conv2D)         (None, 14, 14, 208)          898768    ['max_pooling2d_72[0][0]']
#
#  conv2d_233 (Conv2D)         (None, 14, 14, 48)           576048    ['max_pooling2d_72[0][0]']
#
#  conv2d_234 (Conv2D)         (None, 14, 14, 64)           30784     ['max_pooling2d_72[0][0]']
#
#  concatenate_20 (Concatenat  (None, 14, 14, 512)          0         ['conv2d_229[0][0]',
#  e)                                                                  'conv2d_231[0][0]',
#                                                                      'conv2d_233[0][0]',
#                                                                      'conv2d_234[0][0]']
#
#  conv2d_235 (Conv2D)         (None, 14, 14, 160)          82080     ['concatenate_20[0][0]']
#
#  conv2d_237 (Conv2D)         (None, 14, 14, 224)          1032416   ['concatenate_20[0][0]']
#
#  conv2d_239 (Conv2D)         (None, 14, 14, 64)           819264    ['concatenate_20[0][0]']
#
#  conv2d_240 (Conv2D)         (None, 14, 14, 64)           32832     ['concatenate_20[0][0]']
#
#  concatenate_21 (Concatenat  (None, 14, 14, 512)          0         ['conv2d_235[0][0]',
#  e)                                                                  'conv2d_237[0][0]',
#                                                                      'conv2d_239[0][0]',
#                                                                      'conv2d_240[0][0]']
#
#  conv2d_241 (Conv2D)         (None, 14, 14, 128)          65664     ['concatenate_21[0][0]']
#
#  conv2d_243 (Conv2D)         (None, 14, 14, 256)          1179904   ['concatenate_21[0][0]']
#
#  conv2d_245 (Conv2D)         (None, 14, 14, 64)           819264    ['concatenate_21[0][0]']
#
#  conv2d_246 (Conv2D)         (None, 14, 14, 64)           32832     ['concatenate_21[0][0]']
#
#  concatenate_22 (Concatenat  (None, 14, 14, 512)          0         ['conv2d_241[0][0]',
#  e)                                                                  'conv2d_243[0][0]',
#                                                                      'conv2d_245[0][0]',
#                                                                      'conv2d_246[0][0]']
#
#  conv2d_247 (Conv2D)         (None, 14, 14, 112)          57456     ['concatenate_22[0][0]']
#
#  conv2d_249 (Conv2D)         (None, 14, 14, 288)          1327392   ['concatenate_22[0][0]']
#
#  conv2d_251 (Conv2D)         (None, 14, 14, 64)           819264    ['concatenate_22[0][0]']
#
#  conv2d_252 (Conv2D)         (None, 14, 14, 64)           32832     ['concatenate_22[0][0]']
#
#  concatenate_23 (Concatenat  (None, 14, 14, 528)          0         ['conv2d_247[0][0]',
#  e)                                                                  'conv2d_249[0][0]',
#                                                                      'conv2d_251[0][0]',
#                                                                      'conv2d_252[0][0]']
#
#  conv2d_253 (Conv2D)         (None, 14, 14, 256)          135424    ['concatenate_23[0][0]']
#
#  conv2d_255 (Conv2D)         (None, 14, 14, 320)          1520960   ['concatenate_23[0][0]']
#
#  conv2d_257 (Conv2D)         (None, 14, 14, 128)          1689728   ['concatenate_23[0][0]']
#
#  conv2d_258 (Conv2D)         (None, 14, 14, 128)          67712     ['concatenate_23[0][0]']
#
#  concatenate_24 (Concatenat  (None, 14, 14, 832)          0         ['conv2d_253[0][0]',
#  e)                                                                  'conv2d_255[0][0]',
#                                                                      'conv2d_257[0][0]',
#                                                                      'conv2d_258[0][0]']
#
#  max_pooling2d_78 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_24[0][0]']
#  ng2D)
#
#  conv2d_259 (Conv2D)         (None, 7, 7, 256)            213248    ['max_pooling2d_78[0][0]']
#
#  conv2d_261 (Conv2D)         (None, 7, 7, 320)            2396480   ['max_pooling2d_78[0][0]']
#
#  conv2d_263 (Conv2D)         (None, 7, 7, 128)            2662528   ['max_pooling2d_78[0][0]']
#
#  conv2d_264 (Conv2D)         (None, 7, 7, 128)            106624    ['max_pooling2d_78[0][0]']
#
#  concatenate_25 (Concatenat  (None, 7, 7, 832)            0         ['conv2d_259[0][0]',
#  e)                                                                  'conv2d_261[0][0]',
#                                                                      'conv2d_263[0][0]',
#                                                                      'conv2d_264[0][0]']
#
#  conv2d_265 (Conv2D)         (None, 7, 7, 384)            319872    ['concatenate_25[0][0]']
#
#  conv2d_267 (Conv2D)         (None, 7, 7, 384)            2875776   ['concatenate_25[0][0]']
#
#  conv2d_269 (Conv2D)         (None, 7, 7, 128)            2662528   ['concatenate_25[0][0]']
#
#  conv2d_270 (Conv2D)         (None, 7, 7, 128)            106624    ['concatenate_25[0][0]']
#
#  concatenate_26 (Concatenat  (None, 7, 7, 1024)           0         ['conv2d_265[0][0]',
#  e)                                                                  'conv2d_267[0][0]',
#                                                                      'conv2d_269[0][0]',
#                                                                      'conv2d_270[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 7, 7, 1024)           0         ['concatenate_26[0][0]']
#  gePooling2D)
#
#  dropout_6 (Dropout)         (None, 7, 7, 1024)           0         ['average_pooling2d_6[0][0]']
#
#  flatten_12 (Flatten)        (None, 50176)                0         ['dropout_6[0][0]']
#
#  dense_40 (Dense)            (None, 1000)                 5017700   ['flatten_12[0][0]']
#                                                           0
#
#  dense_41 (Dense)            (None, 1000)                 1001000   ['dense_40[0][0]']
#
# ==================================================================================================
# Total params: 75454784 (287.84 MB)
# Trainable params: 75454784 (287.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## VGGNet

# %%
vggnet = Sequential([
    layers.Input(shape=(224, 224, 3), name="Input"),
    layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    layers.Flatten(), 
    layers.Dense(units=25088, activation="relu"),
    layers.Dense(units=4096, activation="relu"),
    layers.Dense(units=4096, activation="relu"),
    layers.Dense(units=1000, activation="softmax")
])

vggnet.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_271 (Conv2D)         (None, 222, 222, 64)      1792
#
#  conv2d_272 (Conv2D)         (None, 220, 220, 64)      36928
#
#  max_pooling2d_81 (MaxPooli  (None, 110, 110, 64)      0
#  ng2D)
#
#  conv2d_273 (Conv2D)         (None, 108, 108, 128)     73856
#
#  conv2d_274 (Conv2D)         (None, 106, 106, 128)     147584
#
#  max_pooling2d_82 (MaxPooli  (None, 53, 53, 128)       0
#  ng2D)
#
#  conv2d_275 (Conv2D)         (None, 51, 51, 256)       295168
#
#  conv2d_276 (Conv2D)         (None, 49, 49, 256)       590080
#
#  max_pooling2d_83 (MaxPooli  (None, 24, 24, 256)       0
#  ng2D)
#
#  conv2d_277 (Conv2D)         (None, 22, 22, 512)       1180160
#
#  conv2d_278 (Conv2D)         (None, 20, 20, 512)       2359808
#
#  conv2d_279 (Conv2D)         (None, 18, 18, 512)       2359808
#
#  max_pooling2d_84 (MaxPooli  (None, 9, 9, 512)         0
#  ng2D)
#
#  conv2d_280 (Conv2D)         (None, 7, 7, 512)         2359808
#
#  conv2d_281 (Conv2D)         (None, 5, 5, 512)         2359808
#
#  conv2d_282 (Conv2D)         (None, 3, 3, 512)         2359808
#
#  max_pooling2d_85 (MaxPooli  (None, 1, 1, 512)         0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 512)               0
#
#  dense_42 (Dense)            (None, 25088)             12870144
#
#  dense_43 (Dense)            (None, 4096)              102764544
#
#  dense_44 (Dense)            (None, 4096)              16781312
#
#  dense_45 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 150637608 (574.64 MB)
# Trainable params: 150637608 (574.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Eddy
